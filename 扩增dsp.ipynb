# %% [markdown]
# <a href="https://colab.research.google.com/github/rockey1006/Python3/blob/master/%E6%89%A9%E5%A2%9Edsp.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
from zipfile import ZipFile
with ZipFile('/content/drive/MyDrive/rotation4.zip', 'r') as zipObj:
   # Extract all the contents of zip file in different directory
   zipObj.extractall('/')

# %%
from zipfile import ZipFile
with ZipFile('/content/drive/MyDrive/LFW_one1.zip', 'r') as zipObj:
   # Extract all the contents of zip file in different directory
   zipObj.extractall('/agumented_image_processing')

# %%
from zipfile import ZipFile
with ZipFile('/content/drive/MyDrive/agumented617/dsp4/dsp4.zip', 'r') as zipObj:
   # Extract all the contents of zip file in different directory
   zipObj.extractall('/agumented_image_processing_plus')

# %%
import os
srcPath="/content/rotation5/batch002/"
dstPath =  "/agumented_image_processing_plus/agumented_image_processing/content/LFW_one1/"

def copyfile(srcPath,dstPath):
    for name_file in os.listdir(dstPath):
      keyword=name_file
      #print(keyword)
      for name_file1 in os.listdir(srcPath):
        if keyword in name_file1:
          count=0
          count2 = 503
         # for file in sorted((os.listdir(srcPath+name_file1))):
            #for x in  regex.findall(file): 
              #if float(x)<1.1:
                #print(x)
          path = os.path.join(srcPath+str(name_file1))
          with open(path, 'rb') as rstream:
            container = rstream.read()
            path2 = os.path.join(dstPath+str(name_file)+'/'+ str(name_file)+'_0%3d'%(count2)+'_0.png')
                  #if count <1:#9-shot
            print(path2)
            with open(path2, 'wb') as wstream:
              wstream.write(container)
              count2+=1
              count+=1
copyfile(srcPath,dstPath)

# %%
# !zip -r /content/drive/MyDrive/agumented617/dsp4/dsp7.zip  /agumented_image_processing_plus/agumented_image_processing/content/LFW_one1/
# Out:
# Streaming output truncated to the last 5000 lines.
#   adding: agumented_image_processing_plus/agumented_image_processing/content/LFW_one1/Keira_Knightley/Keira_Knightley_0700_0.png (deflated 5%)
#   adding: agumented_image_processing_plus/agumented_image_processing/content/LFW_one1/Keira_Knightley/Keira_Knightley_0800_0.png (deflated 0%)
#   adding: agumented_image_processing_plus/agumented_image_processing/content/LFW_one1/Rich_Gannon/ (stored 0%)
#   adding: agumented_image_processing_plus/agumented_image_processing/content/LFW_one1/Rich_Gannon/Rich_Gannon_0001_0.png (deflated 0%)
#   adding: agumented_image_processing_plus/agumented_image_processing/content/LFW_one1/Marilyn_Monroe/ (stored 0%)
#   adding: agumented_image_processing_plus/agumented_image_processing/content/LFW_one1/Marilyn_Monroe/Marilyn_Monroe_0700_0.png (deflated 24%)
#   adding: agumented_image_processing_plus/agumented_image_processing/content/LFW_one1/Marilyn_Monroe/Marilyn_Monroe_0600_0.png (deflated 17%)
# ...
